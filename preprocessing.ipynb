# %% [markdown]
# # LOADING A NON CHEATING IMAGE

# %%
import cv2
image_path = r"D:\CV_DATASETS\noncheat\Screenshot 2024-02-22 022941.jpg"
image = cv2.imread(image_path)
image
# Out:
# array([[[254, 254, 254],
#         [252, 252, 252],
#         [221, 221, 221],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [252, 252, 252],
#         [221, 221, 221],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [252, 252, 252],
#         [221, 221, 221],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[254, 254, 254],
#         [252, 252, 252],
#         [221, 221, 221],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [252, 252, 252],
#         [221, 221, 221],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [252, 252, 252],
#         [221, 221, 221],
# ...

# %%
from matplotlib import pyplot as plt
import cv2

image_path = r"D:\CV_DATASETS\noncheat\Screenshot 2024-02-22 022941.jpg"
image = cv2.imread(image_path)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ### CONVERTING TO GRAY SCALE

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)


plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ### REDUCE NOISE AND SMOOTHENING THE IMAGE

# %%
# Apply Gaussian Blur to reduce noise and smooth the image
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

# Display the blurred image
plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred Image')
plt.axis('off') 
plt.show()

# %% [markdown]
# ### BINARY IMAGE - BLACK AND WHITE

# %%
# Apply thresholding to create a binary image
threshold_value = 127
max_value = 255
_, binary_image = cv2.threshold(blurred_image, threshold_value, max_value, cv2.THRESH_BINARY)

# Display the binary image
plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image')
plt.axis('off') 
plt.show()

# %% [markdown]
# ### MORPHOLOGICAL CLOSING

# %%
kernel_size = (5, 5)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)

closed_image = cv2.morphologyEx(binary_image, cv2.MORPH_CLOSE, kernel)

plt.imshow(closed_image, cmap='gray')
plt.title('Closed Image')
plt.axis('off') 
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

image_path = r"D:\CV_DATASETS\ques_data\qp.jpg"  
original_image = cv2.imread(image_path)
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

question_roi = (222, 86, 815, 960)

cv2.rectangle(original_image_rgb, (question_roi[0], question_roi[1]), 
              (question_roi[0] + question_roi[2], question_roi[1] + question_roi[3]), 
              (255, 0, 0), 2)  
plt.imshow(original_image_rgb)
plt.title('Original Image with Question Area Marked')
plt.axis('off')
plt.show()

# %% [markdown]
# ### MARKING BOURNDARIES

# %%
import cv2
from matplotlib import pyplot as plt

image_path = r"D:\CV_DATASETS\ques_data\qp.jpg"  
original_image = cv2.imread(image_path)
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

question_roi_1 = (216, 100, 500, 370)   
question_roi_2 = (231, 578, 300, 400)  

cv2.rectangle(original_image_rgb, (question_roi_1[0], question_roi_1[1]), 
              (question_roi_1[0] + question_roi_1[2], question_roi_1[1] + question_roi_1[3]), 
              (255, 0, 0), 2)  

cv2.rectangle(original_image_rgb, (question_roi_2[0], question_roi_2[1]), 
              (question_roi_2[0] + question_roi_2[2], question_roi_2[1] + question_roi_2[3]), 
              (0, 255, 0), 2)  

plt.imshow(original_image_rgb)
plt.title('Original Image with Questions Marked')
plt.axis('off')
plt.show()

# %%
new_width, new_height = 1270, 1074

resized_closed_image = cv2.resize(closed_image, (new_width, new_height))

# %% [markdown]
# ### TESTING BOUNDARIES WITH HEATMAP

# %%
import cv2
from matplotlib import pyplot as plt

original_image = resized_closed_image
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

question_roi_1 = (216, 100, 500, 370)  
question_roi_2 = (231, 578, 300, 400)  

cv2.rectangle(original_image_rgb, (question_roi_1[0], question_roi_1[1]), 
              (question_roi_1[0] + question_roi_1[2], question_roi_1[1] + question_roi_1[3]), 
              (255, 0, 0), 2) 

cv2.rectangle(original_image_rgb, (question_roi_2[0], question_roi_2[1]), 
              (question_roi_2[0] + question_roi_2[2], question_roi_2[1] + question_roi_2[3]), 
              (0, 255, 0), 2)  

plt.imshow(original_image_rgb)
plt.title('Original Image with Questions Marked')
plt.axis('off')
plt.show()

# %% [markdown]
# # LOADING A CHEATING IMAGE

# %%
import cv2
image_path = r"D:\CV_DATASETS\cheat\Screenshot 2024-02-22 022650.jpg"
image = cv2.imread(image_path)
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
from matplotlib import pyplot as plt
import cv2

image_path = r"D:\CV_DATASETS\cheat\Screenshot 2024-02-22 022650.jpg"
image = cv2.imread(image_path)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ### CONVERTING TO GRAY SCALE

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ### REDUCE NOISE AND SMOOTHENING THE IMAGE

# %%
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred Image')
plt.axis('off') 
plt.show()

# %% [markdown]
# ### BINARY IMAGE - BLACK AND WHITE

# %%
threshold_value = 127 
max_value = 255
_, binary_image = cv2.threshold(blurred_image, threshold_value, max_value, cv2.THRESH_BINARY)

plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ### MORPHOLOGICAL CLOSING

# %%
kernel_size = (5, 5)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)

closed_image = cv2.morphologyEx(binary_image, cv2.MORPH_CLOSE, kernel)

plt.imshow(closed_image, cmap='gray')
plt.title('Closed Image')
plt.axis('off')
plt.show()

# %%
new_width, new_height = 1270, 1074

resized_closed_image = cv2.resize(closed_image, (new_width, new_height))

# %% [markdown]
# ### MARKING BOUNDARIES

# %%
import cv2
from matplotlib import pyplot as plt

original_image = resized_closed_image
original_image_rgb_c = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

question_roi_1 = (216, 100, 500, 370)
question_roi_2 = (231, 578, 300, 400) 

cv2.rectangle(original_image_rgb_c, (question_roi_1[0], question_roi_1[1]), 
              (question_roi_1[0] + question_roi_1[2], question_roi_1[1] + question_roi_1[3]), 
              (255, 0, 0), 2)  

cv2.rectangle(original_image_rgb_c, (question_roi_2[0], question_roi_2[1]), 
              (question_roi_2[0] + question_roi_2[2], question_roi_2[1] + question_roi_2[3]), 
              (0, 255, 0), 2) 

plt.imshow(original_image_rgb_c)
plt.title('Original Image with Questions Marked')
plt.axis('off')
plt.show()

# %% [markdown]
# ## COMPARING CHEAT AND NON-CHEAT VISUALLY

# %%
import matplotlib.pyplot as plt


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))

ax1.imshow(original_image_rgb_c)
ax1.set_title('Cheat Heatmap')
ax1.axis('off') 

ax2.imshow(original_image_rgb)
ax2.set_title('Non-Cheat Heatmap')
ax2.axis('off') 

plt.show()
